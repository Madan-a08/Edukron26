# %%
text = "Edukron Data Science and Data Engineering Batch 2026"

# %%
# 1. Write the indexing expression to print "Edukron".

print("Positive Indexing :", text[0:7])
print("Negative Indexing :", text[-52:-45])
# Out:
# Positive Indexing : Edukron
# Negative Indexing : Edukron

# %%
# 2. Write the indexing expression to print "Data" (first occurrence).

print("Positive Indexing :", text[8:12])
print("Negative Indexing :", text[-44:-40])
# Out:
# Positive Indexing : Data
# Negative Indexing : Data

# %%
# 3. Write the indexing expression to print "Science".

print("Positive Indexing :", text[13:20])
print("Negative Indexing :", text[-39:-32])
# Out:
# Positive Indexing : Science
# Negative Indexing : Science

# %%
# 4. Write the indexing expression to print "and".

print("Positive Indexing :", text[21:24])
print("Negative Indexing :", text[-31:-28])
# Out:
# Positive Indexing : and
# Negative Indexing : and

# %%
# 5. Write the indexing expression to print "Data Engineering".

print("Positive Indexing :", text[25:41])
print("Negative Indexing :", text[-27:-11])
# Out:
# Positive Indexing : Data Engineering
# Negative Indexing : Data Engineering

# %%
# 6. Write the indexing expression to print "Engineering".

print("Positive Indexing :", text[30:41])
print("Negative Indexing :", text[-22:-11])
# Out:
# Positive Indexing : Engineering
# Negative Indexing : Engineering

# %%
# 7. Write the indexing expression to print "Batch".

print("Positive Indexing :", text[42:47])
print("Negative Indexing :", text[-10:-5])
# Out:
# Positive Indexing : Batch
# Negative Indexing : Batch

# %%
# 8. Write the indexing expression to print "2026".

print("Positive Indexing :", text[48:52])
print("Negative Indexing :", text[-4:])
# Out:
# Positive Indexing : 2026
# Negative Indexing : 2026

# %%
# 9. Write the indexing expression to print "Science and Data".

print("Positive Indexing :", text[13:29])
print("Negative Indexing :", text[-39:-23])
# Out:
# Positive Indexing : Science and Data
# Negative Indexing : Science and Data

# %%
# 10. Write the indexing expression to print "Data Science and Data Engineering Batch".

print("Positive Indexing :", text[8:47])
print("Negative Indexing :", text[-44:-5])
# Out:
# Positive Indexing : Data Science and Data Engineering Batch
# Negative Indexing : Data Science and Data Engineering Batch
